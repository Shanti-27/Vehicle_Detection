# %%
# Import necessary Libraries
import numpy as np
import cv2
from time import sleep

min_width_rec = 80 
min_height_rec = 80

offset = 6 # Allow error between pixel
delay = 60 # FPS to video
carros = 0 # counter for the number of detected vehicles

count_lines_pos = 550
detec = []
def central_handle(x,y,w,h): # this will calculate the center cooridinate of a rectangle
    x1 = int(w/2)
    y1 = int(h/2)
    cx = x + x1
    cy = y + y1
    return cx, cy

# Enable web camera
cap = cv2.VideoCapture('video.mp4')
algo = cv2.bgsegm.createBackgroundSubtractorMOG()
#algo = cv2.createBackgroundSubtractorMOG2()
while True:
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray, (3,3),5)
    
    # Applying on each frame
    img_sub = algo.apply(blur)
    dilat = cv2.dilate(img_sub, np.ones((5,5)))
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(5,5))
    dilatada = cv2.morphologyEx(dilat, cv2.MORPH_CLOSE, kernel)
    dilatada = cv2.morphologyEx(dilatada, cv2.MORPH_CLOSE, kernel)
    counterShape, h = cv2.findContours(dilatada, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    
    cv2.line(frame, (25, count_lines_pos), (1200, count_lines_pos), (0,0,255),3)
    #line(img, pt1, pt2, color,thickness)
    
    for (i, c) in enumerate(counterShape):
        (x,y,w,h) = cv2.boundingRect(c)
        validar_contorno = (w >=min_width_rec) and (h >=min_height_rec)
        
        if not validar_contorno:
            continue
            
        cv2.rectangle(frame, (x, y), (x+w, y+h),(0,255,0),2)
        cv2.putText(frame, "vehicle" + str(carros), (x, y-20), cv2.FONT_HERSHEY_TRIPLEX, 1, (255,244,0),2)
        # putText(img, text, org, fontFace, fontScale, color, thickness)
        
        center = central_handle(x,y,w,h)
        detec.append(center)
        cv2.circle(frame, center, 4, (255,100,100),-1)
        #circle(img, center, radius, color[, thickness
        
        # Loop 
        for (x,y) in detec:
            if y <(count_lines_pos + offset) and y >(count_lines_pos - offset):
                carros +=1
                cv2.line(frame, (25, count_lines_pos), (1200, count_lines_pos), (0,0,255),3)
                detec.remove((x,y))
                print("Vehicle is detected :" + str(carros))
    cv2.putText(frame, "Vehicle Count :" + str(carros), (450,70),cv2.FONT_HERSHEY_SIMPLEX, 2, (0,255,255), 5)
      # putText(img, text, org, fontFace, fontScale, color, thickness)  
        
        # rectangle(img, pt1, pt2, color, thickness)    
    
    cv2.imshow("Original Video with Vehicle Count", frame)
    
    if cv2.waitKey(1)==13:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# Vehicle is detected :1
# Vehicle is detected :2
# Vehicle is detected :3
# Vehicle is detected :4
# Vehicle is detected :5
# Vehicle is detected :6
# Vehicle is detected :7
# Vehicle is detected :8
# Vehicle is detected :9
# Vehicle is detected :10
# Vehicle is detected :11
# Vehicle is detected :12
# Vehicle is detected :13
# Vehicle is detected :14
# Vehicle is detected :15
# Vehicle is detected :16
# Vehicle is detected :17
# Vehicle is detected :18
# Vehicle is detected :19
# Vehicle is detected :20
# Vehicle is detected :21
# Vehicle is detected :22
# Vehicle is detected :23
# Vehicle is detected :24
# Vehicle is detected :25
# Vehicle is detected :26
# Vehicle is detected :27
# Vehicle is detected :28
# Vehicle is detected :29
# Vehicle is detected :30
# Vehicle is detected :31
# Vehicle is detected :32
# Vehicle is detected :33
# Vehicle is detected :34
# Vehicle is detected :35
# Vehicle is detected :36
# Vehicle is detected :37
# Vehicle is detected :38
# Vehicle is detected :39
# Vehicle is detected :40
# Vehicle is detected :41
# Vehicle is detected :42
# Vehicle is detected :43
# Vehicle is detected :44
# Vehicle is detected :45
# Vehicle is detected :46
# Vehicle is detected :47
# Vehicle is detected :48
# Vehicle is detected :49
# Vehicle is detected :50
# Vehicle is detected :51
# Vehicle is detected :52
# Vehicle is detected :53
# Vehicle is detected :54
# Vehicle is detected :55
# Vehicle is detected :56
# Vehicle is detected :57
# Vehicle is detected :58
# Vehicle is detected :59
# Vehicle is detected :60
# Vehicle is detected :61
# Vehicle is detected :62
# Vehicle is detected :63
# Vehicle is detected :64
# Vehicle is detected :65
# Vehicle is detected :66
# Vehicle is detected :67
# Vehicle is detected :68
# Vehicle is detected :69
# Vehicle is detected :70
# Vehicle is detected :71
# Vehicle is detected :72
# Vehicle is detected :73
# Vehicle is detected :74
# Vehicle is detected :75
# Vehicle is detected :76
# Vehicle is detected :77
# Vehicle is detected :78
# Vehicle is detected :79
# Vehicle is detected :80
# Vehicle is detected :81
# Vehicle is detected :82
# Vehicle is detected :83
# Vehicle is detected :84
# Vehicle is detected :85
# Vehicle is detected :86
# Vehicle is detected :87
# Vehicle is detected :88
# Vehicle is detected :89
# Vehicle is detected :90
# Vehicle is detected :91
# Vehicle is detected :92
# Vehicle is detected :93
# Vehicle is detected :94
# Vehicle is detected :95
# Vehicle is detected :96
# Vehicle is detected :97
# Vehicle is detected :98
# Vehicle is detected :99
# Vehicle is detected :100
# Vehicle is detected :101
# Vehicle is detected :102
# Vehicle is detected :103
# Vehicle is detected :104
# Vehicle is detected :105
# Vehicle is detected :106
# Vehicle is detected :107
# Vehicle is detected :108
# Vehicle is detected :109
# Vehicle is detected :110
# Vehicle is detected :111
# Vehicle is detected :112
# Vehicle is detected :113
# Vehicle is detected :114
# Vehicle is detected :115
# Vehicle is detected :116
# Vehicle is detected :117
# Vehicle is detected :118
# Vehicle is detected :119
# Vehicle is detected :120
# Vehicle is detected :121
# Vehicle is detected :122
# Vehicle is detected :123
# Vehicle is detected :124
# Vehicle is detected :125
# Vehicle is detected :126
# Vehicle is detected :127
# Vehicle is detected :128
# Vehicle is detected :129
# Vehicle is detected :130
# Vehicle is detected :131
# Vehicle is detected :132
# Vehicle is detected :133
# Vehicle is detected :134
# Vehicle is detected :135
# Vehicle is detected :136
# Vehicle is detected :137
# Vehicle is detected :138
# Vehicle is detected :139
# Vehicle is detected :140
# Vehicle is detected :141
# Vehicle is detected :142
# Vehicle is detected :143
# Vehicle is detected :144
# Vehicle is detected :145
# Vehicle is detected :146
# Vehicle is detected :147
# Vehicle is detected :148
# Vehicle is detected :149
# Vehicle is detected :150
# Vehicle is detected :151
# Vehicle is detected :152
# Vehicle is detected :153
# Vehicle is detected :154
# Vehicle is detected :155
# Vehicle is detected :156
# Vehicle is detected :157
# Vehicle is detected :158
# Vehicle is detected :159
# Vehicle is detected :160
# Vehicle is detected :161
# Vehicle is detected :162
# Vehicle is detected :163
# Vehicle is detected :164
# Vehicle is detected :165
# Vehicle is detected :166
# Vehicle is detected :167
# Vehicle is detected :168
# Vehicle is detected :169
# Vehicle is detected :170
# Vehicle is detected :171
# Vehicle is detected :172
# Vehicle is detected :173
# Vehicle is detected :174
# Vehicle is detected :175
# Vehicle is detected :176
# Vehicle is detected :177
# Vehicle is detected :178
# Vehicle is detected :179
# Vehicle is detected :180
# Vehicle is detected :181
# Vehicle is detected :182
# Vehicle is detected :183
# Vehicle is detected :184
# Vehicle is detected :185
# Vehicle is detected :186
# Vehicle is detected :187
# Vehicle is detected :188
# Vehicle is detected :189
# Vehicle is detected :190
# Vehicle is detected :191
# Vehicle is detected :192
# Vehicle is detected :193
# Vehicle is detected :194
# Vehicle is detected :195
# Vehicle is detected :196
# Vehicle is detected :197
# Vehicle is detected :198
# Vehicle is detected :199
# Vehicle is detected :200
# Vehicle is detected :201
# Vehicle is detected :202
# Vehicle is detected :203
# Vehicle is detected :204
# Vehicle is detected :205
# Vehicle is detected :206
# Vehicle is detected :207
# Vehicle is detected :208
# Vehicle is detected :209
# Vehicle is detected :210
# Vehicle is detected :211
# Vehicle is detected :212
# Vehicle is detected :213
# Vehicle is detected :214
# Vehicle is detected :215
# Vehicle is detected :216
# Vehicle is detected :217
# Vehicle is detected :218
# Vehicle is detected :219
# Vehicle is detected :220
# Vehicle is detected :221
# Vehicle is detected :222
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-ed08c594f989> in <module>
#      26 while True:
#      27     ret, frame = cap.read()
# ---> 28     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#      29     blur = cv2.GaussianBlur(gray, (3,3),5)
#      30
#
# error: OpenCV(4.8.1) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
